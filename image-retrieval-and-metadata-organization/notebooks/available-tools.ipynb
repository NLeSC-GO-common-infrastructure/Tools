# %% [markdown]
# # GO tool for Image Retrieval and Metadata Organization
#
# In this notebook we have explored existing open-source tools that allow one to search and retrieve satellite imagery and to store the corresponding metadata for subsequent queries.

# %% [markdown]
# ## 1. Image Search

# %% [markdown]
# Python-library or command line tool `sat-search`.

# %%
from satsearch import Search

# %%
search = Search.search(
    url="https://earth-search.aws.element84.com/v0",
    collections=["sentinel-s2-l2a-cogs"],
    datetime="2018-02-25/2018-04-25",
    # query sentinel-2 tile 5VNK
    query=[
        "sentinel:utm_zone=5",
        "sentinel:latitude_band=V",
        "sentinel:grid_square=NK"
    ]
)
items = search.items()
len(items)
# Out:
# 29

# %%
summary = items.summary(['date', 'id', 'eo:cloud_cover'])
print(summary)
# Out:
# Items (29):
# date                      id                        eo:cloud_cover
# 2018-04-24                S2B_5VNK_20180424_0_L2A   76.86
# 2018-04-23                S2A_5VNK_20180423_0_L2A   84.82
# 2018-04-21                S2B_5VNK_20180421_0_L2A   83.26
# 2018-04-19                S2A_5VNK_20180419_0_L2A   4.97
# 2018-04-18                S2B_5VNK_20180418_0_L2A   87.24
# 2018-04-16                S2A_5VNK_20180416_0_L2A   38.82
# 2018-04-14                S2B_5VNK_20180414_0_L2A   36.32
# 2018-04-13                S2A_5VNK_20180413_0_L2A   19.75
# 2018-04-11                S2B_5VNK_20180411_0_L2A   87.31
# 2018-04-09                S2A_5VNK_20180409_0_L2A   42.17
# 2018-04-08                S2B_5VNK_20180408_0_L2A   33.05
# 2018-04-06                S2A_5VNK_20180406_0_L2A   85.03
# 2018-04-03                S2A_5VNK_20180403_0_L2A   53.12
# 2018-04-01                S2B_5VNK_20180401_0_L2A   52.46
# 2018-03-30                S2A_5VNK_20180330_0_L2A   52.73
# 2018-03-29                S2B_5VNK_20180329_0_L2A   55.86
# 2018-03-27                S2A_5VNK_20180327_0_L2A   79.81
# 2018-03-25                S2B_5VNK_20180325_1_L2A   0
# 2018-03-24                S2A_5VNK_20180324_0_L2A   59.91
# 2018-03-22                S2B_5VNK_20180322_0_L2A   67.66
# 2018-03-19                S2B_5VNK_20180319_0_L2A   65.88
# 2018-03-15                S2B_5VNK_20180315_0_L2A   44.18
# 2018-03-14                S2A_5VNK_20180314_0_L2A   71.62
# 2018-03-10                S2A_5VNK_20180310_0_L2A   68.59
# 2018-03-07                S2A_5VNK_20180307_0_L2A   40.26
# 2018-03-05                S2B_5VNK_20180305_0_L2A   0
# 2018-03-04                S2A_5VNK_20180304_0_L2A   46.6
# 2018-02-28                S2A_5VNK_20180228_0_L2A   73.07
# 2018-02-25                S2A_5VNK_20180225_0_L2A   59.37

# %%
# save outcome of the search to GeoJSON format
items.save('results.json')

# %% [markdown]
# ## 2. Download
# For images in public repositories (Landsat 8, Sentinel 2 L2A) direct download is possible via `sat-stac`. For Sentinel 2 L1C, Ou's tool from Google Cloud Storage.

# %%
from satstac import ItemCollection

filename_template = '${collection}/${sentinel:utm_zone}/${sentinel:latitude_band}/${sentinel:grid_square}/${id}'

# assets to retrieve
assets = ('metadata', 'B01')

# %%
# load search results
items = ItemCollection.open('results.json')

for item in items:
    for asset in assets:
        item.download(asset, filename_template=filename_template)

# %% [markdown]
# ## 3. Store Metadata
#
# - Parse `GeoJSON` and export it to SQL datatabase e.g. via `geopandas` (NOTE: only subset of attributes are parsed, e.g. assets are excluded):

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('results.json')
gdf.head()
# Out:
#                         id                   datetime     platform  \
# 0  S2B_5VNK_20180424_0_L2A  2018-04-24T21:55:27+00:00  sentinel-2b
# 1  S2A_5VNK_20180423_0_L2A  2018-04-23T21:35:31+00:00  sentinel-2a
# 2  S2B_5VNK_20180421_0_L2A  2018-04-21T21:45:28+00:00  sentinel-2b
# 3  S2A_5VNK_20180419_0_L2A  2018-04-19T21:55:30+00:00  sentinel-2a
# 4  S2B_5VNK_20180418_0_L2A  2018-04-18T21:35:27+00:00  sentinel-2b
#
#   constellation  gsd  data_coverage  view:off_nadir  eo:cloud_cover  \
# 0    sentinel-2   10          43.06               0           76.86
# 1    sentinel-2   10          99.33               0           84.82
# 2    sentinel-2   10         100.00               0           83.26
# 3    sentinel-2   10          42.64               0            4.97
# 4    sentinel-2   10          99.32               0           87.24
#
#    proj:epsg sentinel:latitude_band sentinel:grid_square sentinel:sequence  \
# 0      32605                      V                   NK                 0
# 1      32605                      V                   NK                 0
# 2      32605                      V                   NK                 0
# 3      32605                      V                   NK                 0
# 4      32605                      V                   NK                 0
#
#                                  sentinel:product_id  \
# 0  S2B_MSIL2A_20180424T215529_N0001_R029_T05VNK_2...
# 1  S2A_MSIL2A_20180423T213531_N0001_R086_T05VNK_2...
# 2  S2B_MSIL2A_20180421T214529_N0001_R129_T05VNK_2...
# 3  S2A_MSIL2A_20180419T215531_N0001_R029_T05VNK_2...
# 4  S2B_MSIL2A_20180418T213529_N0001_R086_T05VNK_2...
#
#                             created                           updated  \
# 0  2020-09-27T01:37:37.775002+00:00  2020-09-27T01:37:37.775002+00:00
# 1  2020-10-02T06:23:26.086000+00:00  2020-10-02T06:23:26.086000+00:00
# 2  2020-09-08T11:58:18.973000+00:00  2020-09-08T11:58:18.973000+00:00
# 3  2020-09-26T22:03:57.210999+00:00  2020-09-26T22:03:57.210999+00:00
# 4  2020-09-26T18:44:51.902000+00:00  2020-09-26T18:44:51.902000+00:00
#
#    sentinel:valid_cloud_cover  sentinel:utm_zone  sentinel:data_coverage  \
# 0                        True                  5                   43.06
# 1                        True                  5                   99.33
# 2                        True                  5                  100.00
# 3                        True                  5                   42.64
# 4                        True                  5                   99.32
#
#                                             geometry
# 0  POLYGON ((-152.53008 62.14319, -153.00036 62.1...
# 1  POLYGON ((-150.89497 62.12799, -153.00036 62.1...
# 2  POLYGON ((-150.89497 62.12799, -153.00036 62.1...
# 3  POLYGON ((-152.53548 62.14321, -153.00036 62.1...
# 4  POLYGON ((-150.89497 62.12799, -153.00036 62.1...

# %%
# export table to database
# gdf.to_sql('data', engine)

# load it back as data-frame
# gpd.read_postgis('data', engine)

# %% [markdown]
# - Organize metadata in local STAC catalog, using `sat-stac` (integrated with `sat-search`) or [`pystac`](https://pystac.readthedocs.io/en/latest/):

# %%
import pathlib

from satstac import Catalog, Collection, ItemCollection

# set paths
path_template = '${sentinel:utm_zone}/${sentinel:latitude_band}/${sentinel:grid_square}/${id}'
root_path = pathlib.Path('.').absolute()

# %%
# load search results
items = ItemCollection.open('results.json')

# create local catalog
cat = Catalog({'id': 'Eratosthenes', 'description': 'Catalog for Eratosthenes GO project'})
cat = cat.save('Eratosthenes/catalog.json')

# loop over items found
for item in items:
    col = item.collection()
    
    # if collection not present, add it to catalog
    if col.id not in [c.id for c in cat.catalogs()]:
        cat.add_catalog(col)
        
    # the asset download can be integrated here as well!
    for asset in assets:
        asset_template = (root_path/'${collection}'/path_template).as_posix()
        path = item.download(asset, filename_template=asset_template)
        # modify asset href to local copy 
        item.asset(asset)['href'] = path
        
    # finally add item to catalog
    item_template = '.'.join([path_template, 'json'])
    col.add_item(item, item_template)

# %% [markdown]
# ## 4. Query
#
# Export (subsection of) catalog to `GeoJSON`, import it in `geopandas`.

# %%
from geopandas import GeoDataFrame

# %%
# export all items from the catalog
cat = Catalog.open('Eratosthenes/catalog.json')
items = ItemCollection([i for i in cat.items()])

# import in GeoDataFrame
gdf = GeoDataFrame.from_features(items.geojson())
gdf['id'] = [item.id for item in items]
gdf.head()
# Out:
#                                             geometry              datetime  \
# 0  POLYGON ((-152.53008 62.14319, -153.00036 62.1...  2018-04-24T21:55:27Z
# 1  POLYGON ((-150.89497 62.12799, -153.00036 62.1...  2018-04-23T21:35:31Z
# 2  POLYGON ((-150.89497 62.12799, -153.00036 62.1...  2018-04-21T21:45:28Z
# 3  POLYGON ((-152.53548 62.14321, -153.00036 62.1...  2018-04-19T21:55:30Z
# 4  POLYGON ((-150.89497 62.12799, -153.00036 62.1...  2018-04-18T21:35:27Z
#
#       platform constellation instruments  gsd  data_coverage  view:off_nadir  \
# 0  sentinel-2b    sentinel-2       [msi]   10          43.06               0
# 1  sentinel-2a    sentinel-2       [msi]   10          99.33               0
# 2  sentinel-2b    sentinel-2       [msi]   10         100.00               0
# 3  sentinel-2a    sentinel-2       [msi]   10          42.64               0
# 4  sentinel-2b    sentinel-2       [msi]   10          99.32               0
#
#    eo:cloud_cover  proj:epsg sentinel:latitude_band sentinel:grid_square  \
# 0           76.86      32605                      V                   NK
# 1           84.82      32605                      V                   NK
# 2           83.26      32605                      V                   NK
# 3            4.97      32605                      V                   NK
# 4           87.24      32605                      V                   NK
#
#   sentinel:sequence                                sentinel:product_id  \
# 0                 0  S2B_MSIL2A_20180424T215529_N0001_R029_T05VNK_2...
# 1                 0  S2A_MSIL2A_20180423T213531_N0001_R086_T05VNK_2...
# 2                 0  S2B_MSIL2A_20180421T214529_N0001_R129_T05VNK_2...
# 3                 0  S2A_MSIL2A_20180419T215531_N0001_R029_T05VNK_2...
# 4                 0  S2B_MSIL2A_20180418T213529_N0001_R086_T05VNK_2...
#
#                     created                   updated  \
# 0  2020-09-27T01:37:37.775Z  2020-09-27T01:37:37.775Z
# 1  2020-10-02T06:23:26.086Z  2020-10-02T06:23:26.086Z
# 2  2020-09-08T11:58:18.973Z  2020-09-08T11:58:18.973Z
# 3  2020-09-26T22:03:57.211Z  2020-09-26T22:03:57.211Z
# 4  2020-09-26T18:44:51.902Z  2020-09-26T18:44:51.902Z
#
#    sentinel:valid_cloud_cover  sentinel:utm_zone  sentinel:data_coverage  \
# 0                        True                  5                   43.06
# 1                        True                  5                   99.33
# 2                        True                  5                  100.00
# 3                        True                  5                   42.64
# 4                        True                  5                   99.32
#
#                         id
# 0  S2B_5VNK_20180424_0_L2A
# 1  S2A_5VNK_20180423_0_L2A
# 2  S2B_5VNK_20180421_0_L2A
# 3  S2A_5VNK_20180419_0_L2A
# 4  S2B_5VNK_20180418_0_L2A

# %%
mask = (gdf['eo:cloud_cover'] < 10) & (gdf.platform == 'sentinel-2b')
gdf_subset = gdf[mask]
gdf_subset
# Out:
#                                              geometry              datetime  \
# 17  POLYGON ((-152.51967 62.14316, -153.00036 62.1...  2018-03-25T21:55:23Z
# 25  POLYGON ((-152.53328 62.14320, -153.00036 62.1...  2018-03-05T21:55:19Z
#
#        platform constellation instruments  gsd  data_coverage  view:off_nadir  \
# 17  sentinel-2b    sentinel-2       [msi]   10            NaN               0
# 25  sentinel-2b    sentinel-2       [msi]   10          42.77               0
#
#     eo:cloud_cover  proj:epsg sentinel:latitude_band sentinel:grid_square  \
# 17             0.0      32605                      V                   NK
# 25             0.0      32605                      V                   NK
#
#    sentinel:sequence                                sentinel:product_id  \
# 17                 1  S2B_MSIL2A_20180325T215529_N0001_R029_T05VNK_2...
# 25                 0  S2B_MSIL2A_20180305T215519_N0001_R029_T05VNK_2...
#
#                      created                   updated  \
# 17  2020-09-28T19:40:26.599Z  2020-09-28T19:40:26.599Z
# 25  2020-09-08T08:56:12.672Z  2020-09-08T08:56:12.672Z
#
#     sentinel:valid_cloud_cover  sentinel:utm_zone  sentinel:data_coverage  \
# 17                       False                  5                   43.51
# 25                        True                  5                   42.77
#
#                          id
# 17  S2B_5VNK_20180325_1_L2A
# 25  S2B_5VNK_20180305_0_L2A

# %%
ids = [id for id in gdf_subset.id]
ids
# Out:
# ['S2B_5VNK_20180325_1_L2A', 'S2B_5VNK_20180305_0_L2A']

# %% [markdown]
# ## 5. Import
#
# Apart from the 'manual' search over the local filesystem, `intake` (with plugins) allows to load assets from catalog. NOTE: the `intake-stac` plugin is still under development.

# %%
import intake

# %%
col = intake.open_stac_collection('Eratosthenes/sentinel-s2-l2a-cogs/catalog.json')

# %%
col[ids[0]].B02.metadata
# Out:
# {'title': 'Band 2 (blue)',
#  'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#  'roles': ['data'],
#  'gsd': 10,
#  'eo:bands': [{'name': 'B02',
#    'common_name': 'blue',
#    'center_wavelength': 0.4966,
#    'full_width_half_max': 0.098}],
#  'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/5/V/NK/2018/3/S2B_5VNK_20180325_1_L2A/B02.tif',
#  'proj:shape': [10980, 10980],
#  'proj:transform': [10, 0, 499980, 0, -10, 7000020, 0, 0, 1],
#  'plots': {'geotiff': {'kind': 'image',
#    'x': 'x',
#    'y': 'y',
#    'frame_width': 500,
#    'data_aspect': 1,
#    'rasterize': True,
#    'dynamic': True,
#    'cmap': 'viridis'}},
#  'catalog_dir': ''}

# %%
ds = col[ids[0]].B01.to_dask()
ds
# Out:
# <xarray.DataArray (band: 1, y: 1830, x: 1830)>
# dask.array<open_rasterio-8050c971f1d2f814ad8277c36f6e6060<this-array>, shape=(1, 1830, 1830), dtype=uint16, chunksize=(1, 1830, 1830), chunktype=numpy.ndarray>
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 7e+06 7e+06 7e+06 7e+06 ... 6.89e+06 6.89e+06 6.89e+06
#   * x        (x) float64 5e+05 5.001e+05 5.001e+05 ... 6.097e+05 6.098e+05
# Attributes:
#     transform:           (60.0, 0.0, 499980.0, 0.0, -60.0, 7000020.0)
#     crs:                 +init=epsg:32605
#     res:                 (60.0, 60.0)
#     is_tiled:            1
#     nodatavals:          (0.0,)
#     scales:              (1.0,)
#     offsets:             (0.0,)
#     AREA_OR_POINT:       Area
#     OVR_RESAMPLING_ALG:  AVERAGE

# %%
chunks = dict(band=1, x=512, y=512)
ds2 = col[ids[1]].B01(chunks=chunks).to_dask()
ds2
# Out:
# <xarray.DataArray (band: 1, y: 1830, x: 1830)>
# dask.array<open_rasterio-8d5d267cb08fd640cb862944dc88f066<this-array>, shape=(1, 1830, 1830), dtype=uint16, chunksize=(1, 512, 512), chunktype=numpy.ndarray>
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 7e+06 7e+06 7e+06 7e+06 ... 6.89e+06 6.89e+06 6.89e+06
#   * x        (x) float64 5e+05 5.001e+05 5.001e+05 ... 6.097e+05 6.098e+05
# Attributes:
#     transform:           (60.0, 0.0, 499980.0, 0.0, -60.0, 7000020.0)
#     crs:                 +init=epsg:32605
#     res:                 (60.0, 60.0)
#     is_tiled:            1
#     nodatavals:          (0.0,)
#     scales:              (1.0,)
#     offsets:             (0.0,)
#     AREA_OR_POINT:       Area
#     OVR_RESAMPLING_ALG:  AVERAGE
